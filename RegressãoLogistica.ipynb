# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("./dataset/Wine_Quality_Data.csv")
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
df.describe().T
# Out:
#                        count        mean        std      min       25%  \
# fixed_acidity         6497.0    7.215307   1.296434  3.80000   6.40000
# volatile_acidity      6497.0    0.339666   0.164636  0.08000   0.23000
# citric_acid           6497.0    0.318633   0.145318  0.00000   0.25000
# residual_sugar        6497.0    5.443235   4.757804  0.60000   1.80000
# chlorides             6497.0    0.056034   0.035034  0.00900   0.03800
# free_sulfur_dioxide   6497.0   30.525319  17.749400  1.00000  17.00000
# total_sulfur_dioxide  6497.0  115.744574  56.521855  6.00000  77.00000
# density               6497.0    0.994697   0.002999  0.98711   0.99234
# pH                    6497.0    3.218501   0.160787  2.72000   3.11000
# sulphates             6497.0    0.531268   0.148806  0.22000   0.43000
# alcohol               6497.0   10.491801   1.192712  8.00000   9.50000
# quality               6497.0    5.818378   0.873255  3.00000   5.00000
#
# ...

# %%
df['color'].value_counts(normalize=True)
# Out:
# color
# white    0.753886
# red      0.246114
# Name: proportion, dtype: float64

# %%
df['color'] = df['color'].map({'red': 1, 'white':0})

# %%
corr = df.corr()

df.corr()
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000          0.219008     0.324436
# volatile_acidity           0.219008          1.000000    -0.377981
# citric_acid                0.324436         -0.377981     1.000000
# residual_sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free_sulfur_dioxide       -0.282735         -0.352557     0.133126
# total_sulfur_dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
# color                      0.486740          0.653036    -0.187397
#
# ...

# %%
cols = list(df.columns)
cols_len = len(cols)
features = df.filter(items=cols[:cols_len-1])
features
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
features = df.iloc[:, :-1] #(-1) porque a última coluna é a variável de saída da qualidade

scaler = StandardScaler()
features_standardized = scaler.fit_transform(features)

df_standardized = pd.DataFrame(features_standardized, columns=features.columns)

print("Shape dos dados padronizados:", df_standardized.shape)

df_standardized.head()
# Out:
# Shape dos dados padronizados: (6497, 12)
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0       0.142473          2.188833    -2.192833       -0.744778   0.569958
# 1       0.451036          3.282235    -2.192833       -0.597640   1.197975
# 2       0.451036          2.553300    -1.917553       -0.660699   1.026697
# 3       3.073817         -0.362438     1.661085       -0.744778   0.541412
# 4       0.142473          2.188833    -2.192833       -0.744778   0.569958
#
#    free_sulfur_dioxide  total_sulfur_dioxide   density        pH  sulphates  \
# 0            -1.100140             -1.446359  1.034993  1.813090   0.193097
# 1            -0.311320             -0.862469  0.701486 -0.115073   0.999579
# 2            -0.874763             -1.092486  0.768188  0.258120   0.797958
# 3            -0.762074             -0.986324  1.101694 -0.363868   0.327510
# 4            -1.100140             -1.446359  1.034993  1.813090   0.193097
#
# ...

# %%
df['quality'] = (df['quality'] >= 7).astype(int)

# %%
X = df.drop('quality', axis=1)  # 'quality' é a variável alvo
y = df['quality']

# Convertendo para arrays NumPy
X = X.values
y = y.values

print(X)
print(y)
# Out:
# [[7.4 0.7 0.0 ... 0.56 9.4 'red']
#  [7.8 0.88 0.0 ... 0.68 9.8 'red']
#  [7.8 0.76 0.04 ... 0.65 9.8 'red']
#  ...
#  [6.5 0.24 0.19 ... 0.46 9.4 'white']
#  [5.5 0.29 0.3 ... 0.38 12.8 'white']
#  [6.0 0.21 0.38 ... 0.32 11.8 'white']]
# [5 5 5 ... 6 7 6]

# %%
# Calcular a SVD da matriz de features
U, S, Vt = np.linalg.svd(features, full_matrices=False)

# Obter os dois primeiros principais componentes (PCs)
V_first_two_PCs = Vt[:2, :].T  # Vt é a matriz transposta de V

explained_variance_ratio = (S ** 2) / np.sum(S ** 2)

print("Primeiros dois principais componentes:")
print(V_first_two_PCs)
print("\nRazão da variância explicada:")
print(explained_variance_ratio)
# Out:
# Primeiros dois principais componentes:
# [[-4.72890872e-02  3.63938203e-02]
#  [-2.06891818e-03  1.70133628e-03]
#  [-2.24131397e-03  1.08907185e-03]
#  [-4.44287978e-02  1.97222598e-02]
#  [-3.46422201e-04  4.54722239e-04]
#  [-2.49388518e-01  9.63502865e-01]
#  [-9.63428295e-01 -2.56894342e-01]
#  [-6.71103869e-03  5.05136236e-03]
#  [-2.15904066e-02  1.73833050e-02]
#  [-3.45202958e-03  3.49198042e-03]
#  [-6.97637828e-02  5.99638021e-02]
#  [-1.26581034e-03  3.77022187e-03]]
#
# Razão da variância explicada:
# [9.88735639e-01 8.07264167e-03 2.14021676e-03 9.43747898e-04
#  9.10870616e-05 8.83518930e-06 4.82826588e-06 1.31526156e-06
#  1.00264976e-06 5.85729337e-07 6.08450805e-08 3.98406036e-08]

# %%
# Função sigmoid para regressão logística
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def treinar_regressao_logistica(X_train, y_train, learning_rate=0.1, num_epochs=100):
    n_amostras, n_features = X_train.shape

    pesos = np.zeros(n_features)
    bias = 0

    # Gradiente descendente
    for epoch in range(num_epochs):

        y_pred = sigmoid(np.dot(X_train, pesos) + bias)

        dw = (1 / n_amostras) * np.dot(X_train.T, (y_pred - y_train))
        db = (1 / n_amostras) * np.sum(y_pred - y_train)

        cost = - (1 / n_samples) * np.sum(y_train * np.log(y_pred) + (1 - y_train) * np.log(1 - y_pred))

        pesos -= learning_rate * dw
        bias -= learning_rate * db
        if epoch % 100 == 0:
            print(f'Epoch {epoch}: Custo = {cost}')
            print(f'Gradiente dw: {dw}')
            print(f'Gradiente db: {db}\n')

    return pesos, bias

def predict(X, pesos, bias):
    y_pred = sigmoid(np.dot(X, pesos) + bias)
    return (y_pred > 0.5).astype(int)

# acurácia
def calcular_acuracia(y_true, y_pred):
    acuracia = np.mean(y_true == y_pred)
    return acuracia

# matriz de confusão
def calcular_matriz_confusao(y_true, y_pred):
    TP = np.sum((y_true == 1) & (y_pred == 1))
    TN = np.sum((y_true == 0) & (y_pred == 0))
    FP = np.sum((y_true == 0) & (y_pred == 1))
    FN = np.sum((y_true == 1) & (y_pred == 0))
    confusion_matrix = np.array([[TN, FP], [FN, TP]])
    return confusion_matrix

# relatório de classificação
def calcular_relatorio_classificacao(y_true, y_pred):
    TP = np.sum((y_true == 1) & (y_pred == 1))
    TN = np.sum((y_true == 0) & (y_pred == 0))
    FP = np.sum((y_true == 0) & (y_pred == 1))
    FN = np.sum((y_true == 1) & (y_pred == 0))

    precisao = TP / (TP + FP)
    recall = TP / (TP + FN)
    f1_score = 2 * precisao * recall / (precisao + recall)
    suporte = TP + FN

    relatorio_classificacao = {
        'precisao': precisao,
        'recall': recall,
        'f1-score': f1_score,
        'suporte': suporte
    }

    return relatorio_classificacao

# Dividir os dados em treino e teste
test_size = 0.2
n_amostras = len(X_scaled)
n_test = int(test_size * n_amostras)

indices = np.arange(n_amostras)
np.random.shuffle(indices)

train_idx = indices[:-n_test]
test_idx = indices[-n_test:]

X_train, X_test = X_scaled[train_idx], X_scaled[test_idx]
y_train, y_test = y[train_idx], y[test_idx]


pesos, bias = treinar_regressao_logistica(X_train, y_train, learning_rate=0.1, num_epochs=1000)

y_pred = predict(X_test, pesos, bias)

acuracia = calcular_acuracia(y_test, y_pred)
print(f'Acurácia do modelo: {acuracia:.2f}')

matriz_confusao = calcular_matriz_confusao(y_test, y_pred)
print('Matriz de Confusão:')
print(matriz_confusao)

relatorio = calcular_relatorio_classificacao(y_test, y_pred)
print('\nRelatório de Classificação:')
print(relatorio)
# Out:
# Epoch 0: Custo = 0.5545604193551786
# Gradiente dw: [ 0.02436014  0.06057848 -0.01744999  0.02596695  0.06021855 -0.00412531
#   0.02173337  0.11124267 -0.01169288 -0.01080895 -0.15551577  0.03388245]
# Gradiente db: 0.3026163909195845
#
# Epoch 100: Custo = 0.3349409064663858
# Gradiente dw: [-0.0060896   0.01226425 -0.00156741 -0.01349138  0.00616247 -0.00650611
#   0.00544742  0.00539367 -0.00414882 -0.00959083 -0.02510751 -0.00085536]
# Gradiente db: 0.049354219599099705
#
# Epoch 200: Custo = 0.3212582147019229
# Gradiente dw: [-0.00487421  0.00893229  0.0009658  -0.00949307  0.00382268 -0.00376311
#   0.00387307  0.0023659  -0.0033246  -0.00448298 -0.01212232 -0.00073182]
# Gradiente db: 0.017739491718741493
#
# Epoch 300: Custo = 0.31767677814477974
# Gradiente dw: [-0.00394104  0.00659053  0.00166594 -0.00671663  0.00250807 -0.00229927
#   0.00290035  0.00173482 -0.00259598 -0.00230454 -0.00644812 -0.00068505]
# Gradiente db: 0.00882592375111399
#
# ...

# %%
def plotar_regressao_logistica(X, y, pesos, bias):
    plt.figure(figsize=(10, 6))

    # Plotar pontos de dados
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm', edgecolors='k', s=100, label='Pontos de Dados')

    # Plotar fronteira de decisão (linha de decisão)
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, 0.1),
                           np.arange(x2_min, x2_max, 0.1))
    Z = sigmoid(np.dot(np.c_[xx1.ravel(), xx2.ravel()], pesos) + bias)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.4, cmap='coolwarm')

    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.title('Regressão Logística')
    plt.legend()
    plt.show()

    plotar_regressao_logistica(X_treino, y_treino, pesos, bias)
